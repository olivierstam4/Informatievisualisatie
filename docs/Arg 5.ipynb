# %% [markdown]
# # arg 5 temp

# %%
import pandas as pd
import plotly.express as px

# %%
df_green = pd.read_csv('iso_green.csv')

green_columns = df_green.columns.values

# for item in green_columns[3:]:
#     for second_item in green_columns[3:]:
#         corr = df_green[item].corr(df_green[second_item])
#         if corr >= 0.6 or corr <= -0.6:
#             print(corr, '1: ', item, '2: ', second_item)

# %%
fig = px.scatter_3d(df_green, x='Year', z='Water stress, total freshwater abstraction as % total internal renewable resources', y='Artificial surfaces, % total ', color='ISO3')

fig.show()
